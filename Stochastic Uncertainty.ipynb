# %%
# Importing pandas
import pandas as pd

# %% [markdown]
# # Stochastic Uncertainty

# %%
# Read in the csv file and create a dataframe
df = pd.read_csv('Stochastic Uncertainty.csv', sep=',', skiprows=6, error_bad_lines=False)

# Keep the desired columns
df = df[['[run number]','[step]','covariance_cap_sec_aff','covariance_cap_sec_sus','covariance_cap_sec_aut',
         'covariance_cap_sec_com','covariance_cap_sec_inc','covariance_cap_aff_sus','covariance_cap_aff_aut',
         'covariance_cap_aff_com','covariance_cap_aff_inc', 'covariance_cap_sus_aut', 'covariance_cap_sus_com',
         'covariance_cap_sus_inc', 'covariance_cap_aut_com','covariance_cap_aut_inc','covariance_cap_com_inc']]

# Rename the columns
df = df.rename(columns={'[run number]':'Replication','[step]':'Step','covariance_cap_sec_aff':'Sec-Aff','covariance_cap_sec_sus':'Sec-Sus',
                        'covariance_cap_sec_aut':'Sec-Aut', 'covariance_cap_sec_com':'Sec-Com', 'covariance_cap_sec_inc':'Sec-Inc',
                        'covariance_cap_aff_sus':'Aff-Sus','covariance_cap_aff_aut':'Aff-Aut', 'covariance_cap_aff_com':'Aff-Com',
                        'covariance_cap_aff_inc':'Aff-Inc', 'covariance_cap_sus_aut':'Sus-Aut', 'covariance_cap_sus_com':'Sus-Com',
                        'covariance_cap_sus_inc':'Sus-Inc','covariance_cap_aut_com':'Aut-Com','covariance_cap_aut_inc':'Aut-Inc',
                        'covariance_cap_com_inc':'Com-Inc'})

# Keep only the rows of the last tick
df = df[df["Step"].apply(lambda x: (x > 4))]

# Show the first five rows of the dataframe
df.head()
# Out:
#     Replication  Step   Sec-Aff   Sec-Sus   Sec-Aut   Sec-Com   Sec-Inc  \
# 20            4     5  0.000049  0.000045  0.000021  0.000042  0.000045
# 21            3     5  0.000058  0.000048  0.000030  0.000054  0.000058
# 22            2     5  0.002700  0.002775 -0.000543  0.001372  0.001791
# 23            1     5  0.002473  0.002480 -0.000586  0.001221  0.001604
# 44            5     5  0.000050  0.000049  0.000021  0.000042  0.000041
#
#      Aff-Sus   Aff-Aut   Aff-Com   Aff-Inc   Sus-Aut   Sus-Com   Sus-Inc  \
# 20  0.000049  0.000026  0.000086  0.000111  0.000021  0.000042  0.000045
# 21  0.000058  0.000045  0.000135  0.000166  0.000030  0.000054  0.000058
# 22  0.002700 -0.000555  0.001413  0.001879 -0.000543  0.001372  0.001791
# 23  0.002473 -0.000579  0.001327  0.001768 -0.000586  0.001221  0.001604
# 44  0.000050  0.000024  0.000079  0.000093  0.000021  0.000042  0.000041
#
#      Aut-Com   Aut-Inc   Com-Inc
# 20  0.000023  0.000026  0.000115
# ...

# %%
# Print the min, mean and max of the relation between capabilities security of supply and affordability 
min_cap = df['Sec-Aff'].min()
print(min_cap)

mean_cap = df['Sec-Aff'].mean()
print(mean_cap)

max_cap = df['Sec-Aff'].max()
print(max_cap)
# Out:
# 3.920633093493077e-05
# 0.0016036715285319622
# 0.003555435440846003

# %%
# Create a scatter plot for the relation between capabilities security of supply and affordability
scat = df.plot.scatter(x='Replication', y='Sec-Aff', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities security of supply and sustainability
scat = df.plot.scatter(x='Replication', y='Sec-Sus', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities security of supply and autonomy
scat = df.plot.scatter(x='Replication', y='Sec-Aut', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities security of supply and comfort
scat = df.plot.scatter(x='Replication', y='Sec-Com', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities security of supply and inclusiveness
scat = df.plot.scatter(x='Replication', y='Sec-Inc', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities affordability and sustainability
scat = df.plot.scatter(x='Replication', y='Aff-Sus', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities affordability and autonomy
scat = df.plot.scatter(x='Replication', y='Aff-Aut', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities affordability and comfort
scat = df.plot.scatter(x='Replication', y='Aff-Com', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities affordability and inclusiveness
scat = df.plot.scatter(x='Replication', y='Aff-Inc', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities sustainability and autonomy
scat = df.plot.scatter(x='Replication', y='Sus-Aut', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities sustainability and comfort
scat = df.plot.scatter(x='Replication', y='Sus-Com', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities sustainability and inclusiveness
scat = df.plot.scatter(x='Replication', y='Sus-Inc', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities autonomy and comfort
scat = df.plot.scatter(x='Replication', y='Aut-Com', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities autonomy and inclusiveness
scat = df.plot.scatter(x='Replication', y='Aut-Inc', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between capabilities comfort and inclusiveness
scat = df.plot.scatter(x='Replication', y='Com-Inc', ylim=(-0.005,0.005))
