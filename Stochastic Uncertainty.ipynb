# %%
# Importing pandas
import pandas as pd

# %% [markdown]
# # Stochastic Uncertainty

# %%
# Read in the csv file and create a dataframe
df = pd.read_csv('Stochastic Uncertainty.csv', sep=',', skiprows=6, error_bad_lines=False)

# Keep the desired columns
df = df[['[run number]','[step]','covariance_cap_sec_aff','covariance_cap_sec_sus','covariance_cap_sec_aut',
         'covariance_cap_sec_com','covariance_cap_sec_inc','covariance_cap_aff_sus','covariance_cap_aff_aut',
         'covariance_cap_aff_com','covariance_cap_aff_inc', 'covariance_cap_sus_aut', 'covariance_cap_sus_com',
         'covariance_cap_sus_inc', 'covariance_cap_aut_com','covariance_cap_aut_inc','covariance_cap_com_inc']]

# Rename the columns
df = df.rename(columns={'[run number]':'Replication','[step]':'Step','covariance_cap_sec_aff':'Covariance: Sec-Aff','covariance_cap_sec_sus':'Covariance: Sec-Sus',
                        'covariance_cap_sec_aut':'Covariance: Sec-Aut', 'covariance_cap_sec_com':'Covariance: Sec-Com', 'covariance_cap_sec_inc':'Covariance: Sec-Inc',
                        'covariance_cap_aff_sus':'Covariance: Aff-Sus','covariance_cap_aff_aut':'Covariance: Aff-Aut', 'covariance_cap_aff_com':'Covariance: Aff-Com',
                        'covariance_cap_aff_inc':'Covariance: Aff-Inc', 'covariance_cap_sus_aut':'Covariance: Sus-Aut', 'covariance_cap_sus_com':'Covariance: Sus-Com',
                        'covariance_cap_sus_inc':'Covariance: Sus-Inc','covariance_cap_aut_com':'Covariance: Aut-Com','covariance_cap_aut_inc':'Covariance: Aut-Inc',
                        'covariance_cap_com_inc':'Covariance: Com-Inc'})

# Keep only the rows of the last tick
df = df[df["Step"].apply(lambda x: (x > 4))]

# Show the first five rows of the dataframe
df.head()
# Out:
#     Replication  Step  Covariance: Sec-Aff  Covariance: Sec-Sus  \
# 20            4     5             0.000049             0.000045
# 21            3     5             0.000058             0.000048
# 22            2     5             0.002700             0.002775
# 23            1     5             0.002473             0.002480
# 44            5     5             0.000050             0.000049
#
#     Covariance: Sec-Aut  Covariance: Sec-Com  Covariance: Sec-Inc  \
# 20             0.000021             0.000042             0.000045
# 21             0.000030             0.000054             0.000058
# 22            -0.000543             0.001372             0.001791
# 23            -0.000586             0.001221             0.001604
# 44             0.000021             0.000042             0.000041
#
#     Covariance: Aff-Sus  Covariance: Aff-Aut  Covariance: Aff-Com  \
# 20             0.000049             0.000026             0.000086
# ...

# %%
# Print the min, mean and max of the relation between values security of supply and affordability 
min_cap = df['Covariance: Sec-Aff'].min()
print(min_cap)

mean_cap = df['Covariance: Sec-Aff'].mean()
print(mean_cap)

max_cap = df['Covariance: Sec-Aff'].max()
print(max_cap)
# Out:
# 3.920633093493077e-05
# 0.0016036715285319622
# 0.003555435440846003

# %%
# Create a scatter plot for the relation between values security of supply and affordability
scat = df.plot.scatter(x='Replication', y='Covariance: Sec-Aff', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values security of supply and sustainability
scat = df.plot.scatter(x='Replication', y='Covariance: Sec-Sus', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values security of supply and autonomy
scat = df.plot.scatter(x='Replication', y='Covariance: Sec-Aut', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values security of supply and comfort
scat = df.plot.scatter(x='Replication', y='Covariance: Sec-Com', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values security of supply and inclusiveness
scat = df.plot.scatter(x='Replication', y='Covariance: Sec-Inc', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values affordability and sustainability
scat = df.plot.scatter(x='Replication', y='Covariance: Aff-Sus', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values affordability and autonomy
scat = df.plot.scatter(x='Replication', y='Covariance: Aff-Aut', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values affordability and comfort
scat = df.plot.scatter(x='Replication', y='Covariance: Aff-Com', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values affordability and inclusiveness
scat = df.plot.scatter(x='Replication', y='Covariance: Aff-Inc', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values sustainability and autonomy
scat = df.plot.scatter(x='Replication', y='Covariance: Sus-Aut', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values sustainability and comfort
scat = df.plot.scatter(x='Replication', y='Covariance: Sus-Com', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values sustainability and inclusiveness
scat = df.plot.scatter(x='Replication', y='Covariance: Sus-Inc', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values autonomy and comfort
scat = df.plot.scatter(x='Replication', y='Covariance: Aut-Com', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values autonomy and inclusiveness
scat = df.plot.scatter(x='Replication', y='Covariance: Aut-Inc', ylim=(-0.005,0.005))

# %%
# Create a scatter plot for the relation between values comfort and inclusiveness
scat = df.plot.scatter(x='Replication', y='Covariance: Com-Inc', ylim=(-0.005,0.005))
